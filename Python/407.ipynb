# %% [markdown]
# ## Euler Project Problem 407 - Indempotents
# If we calculate $a^2 mod 6$ for $0 ≤ a ≤ 5$ we get: $0,1,4,3,4,1$.
#
# The largest value of a such that $a^2 ≡ a mod 6$ is $4$.
#
# Let's call $M(n)$ the largest value of $a < n$ such that $a^2 ≡ a (mod n)$.
# So $M(6) = 4$.
#
# Find $∑ M(n)$ for $1 ≤ n ≤ 10^7$.
#
# ### Analysis:
# Lets consider all values of $a$ for a given $N$, not just the largest $a<n$.
# if $a^2 ≡ a (mod n)$, then:
# $$a(a-1) = kn$$ for some integer, k.

# %%
from EulerFunctions import primelist, primeFactors, factors, is_prime
primes = primelist(10000)

# %%
def all_idempotents(n):
    # returns all values of a for a given n.
    out = []
    for a in range(1, n):
        if a**2%n == a:
            out.append(a)
    return out

# %%
N = 500
for i in range(1, N):
    all_a = all_idempotents(i)
    print(i, all_a)
# Out:
# 1 []
# 2 [1]
# 3 [1]
# 4 [1]
# 5 [1]
# 6 [1, 3, 4]
# 7 [1]
# 8 [1]
# 9 [1]
# 10 [1, 5, 6]
# 11 [1]
# 12 [1, 4, 9]
# 13 [1]
# 14 [1, 7, 8]
# 15 [1, 6, 10]
# 16 [1]
# 17 [1]
# 18 [1, 9, 10]
# 19 [1]
# 20 [1, 5, 16]
# 21 [1, 7, 15]
# 22 [1, 11, 12]
# 23 [1]
# 24 [1, 9, 16]
# 25 [1]
# 26 [1, 13, 14]
# 27 [1]
# 28 [1, 8, 21]
# 29 [1]
# 30 [1, 6, 10, 15, 16, 21, 25]
# 31 [1]
# 32 [1]
# 33 [1, 12, 22]
# 34 [1, 17, 18]
# 35 [1, 15, 21]
# 36 [1, 9, 28]
# 37 [1]
# 38 [1, 19, 20]
# 39 [1, 13, 27]
# 40 [1, 16, 25]
# 41 [1]
# 42 [1, 7, 15, 21, 22, 28, 36]
# 43 [1]
# 44 [1, 12, 33]
# 45 [1, 10, 36]
# 46 [1, 23, 24]
# 47 [1]
# 48 [1, 16, 33]
# 49 [1]
# 50 [1, 25, 26]
# 51 [1, 18, 34]
# 52 [1, 13, 40]
# 53 [1]
# 54 [1, 27, 28]
# 55 [1, 11, 45]
# 56 [1, 8, 49]
# 57 [1, 19, 39]
# 58 [1, 29, 30]
# 59 [1]
# 60 [1, 16, 21, 25, 36, 40, 45]
# 61 [1]
# 62 [1, 31, 32]
# 63 [1, 28, 36]
# 64 [1]
# 65 [1, 26, 40]
# 66 [1, 12, 22, 33, 34, 45, 55]
# 67 [1]
# 68 [1, 17, 52]
# 69 [1, 24, 46]
# 70 [1, 15, 21, 35, 36, 50, 56]
# 71 [1]
# 72 [1, 9, 64]
# 73 [1]
# 74 [1, 37, 38]
# 75 [1, 25, 51]
# 76 [1, 20, 57]
# 77 [1, 22, 56]
# 78 [1, 13, 27, 39, 40, 52, 66]
# 79 [1]
# 80 [1, 16, 65]
# 81 [1]
# 82 [1, 41, 42]
# 83 [1]
# 84 [1, 21, 28, 36, 49, 57, 64]
# 85 [1, 35, 51]
# 86 [1, 43, 44]
# 87 [1, 30, 58]
# 88 [1, 33, 56]
# 89 [1]
# 90 [1, 10, 36, 45, 46, 55, 81]
# 91 [1, 14, 78]
# 92 [1, 24, 69]
# 93 [1, 31, 63]
# 94 [1, 47, 48]
# 95 [1, 20, 76]
# 96 [1, 33, 64]
# 97 [1]
# 98 [1, 49, 50]
# 99 [1, 45, 55]
# 100 [1, 25, 76]
# 101 [1]
# 102 [1, 18, 34, 51, 52, 69, 85]
# 103 [1]
# 104 [1, 40, 65]
# 105 [1, 15, 21, 36, 70, 85, 91]
# 106 [1, 53, 54]
# 107 [1]
# 108 [1, 28, 81]
# 109 [1]
# 110 [1, 11, 45, 55, 56, 66, 100]
# 111 [1, 37, 75]
# 112 [1, 49, 64]
# 113 [1]
# 114 [1, 19, 39, 57, 58, 76, 96]
# 115 [1, 46, 70]
# 116 [1, 29, 88]
# 117 [1, 27, 91]
# 118 [1, 59, 60]
# 119 [1, 35, 85]
# 120 [1, 16, 25, 40, 81, 96, 105]
# 121 [1]
# 122 [1, 61, 62]
# 123 [1, 42, 82]
# 124 [1, 32, 93]
# 125 [1]
# 126 [1, 28, 36, 63, 64, 91, 99]
# 127 [1]
# 128 [1]
# 129 [1, 43, 87]
# 130 [1, 26, 40, 65, 66, 91, 105]
# 131 [1]
# 132 [1, 12, 33, 45, 88, 100, 121]
# 133 [1, 57, 77]
# 134 [1, 67, 68]
# 135 [1, 55, 81]
# 136 [1, 17, 120]
# 137 [1]
# 138 [1, 24, 46, 69, 70, 93, 115]
# 139 [1]
# 140 [1, 21, 36, 56, 85, 105, 120]
# 141 [1, 48, 94]
# 142 [1, 71, 72]
# 143 [1, 66, 78]
# 144 [1, 64, 81]
# 145 [1, 30, 116]
# 146 [1, 73, 74]
# 147 [1, 49, 99]
# 148 [1, 37, 112]
# 149 [1]
# 150 [1, 25, 51, 75, 76, 100, 126]
# 151 [1]
# 152 [1, 57, 96]
# 153 [1, 18, 136]
# 154 [1, 22, 56, 77, 78, 99, 133]
# 155 [1, 31, 125]
# 156 [1, 13, 40, 52, 105, 117, 144]
# 157 [1]
# 158 [1, 79, 80]
# 159 [1, 54, 106]
# 160 [1, 65, 96]
# 161 [1, 70, 92]
# 162 [1, 81, 82]
# 163 [1]
# 164 [1, 41, 124]
# 165 [1, 45, 55, 66, 100, 111, 121]
# 166 [1, 83, 84]
# 167 [1]
# 168 [1, 49, 57, 64, 105, 112, 120]
# 169 [1]
# 170 [1, 35, 51, 85, 86, 120, 136]
# 171 [1, 19, 153]
# 172 [1, 44, 129]
# 173 [1]
# 174 [1, 30, 58, 87, 88, 117, 145]
# 175 [1, 50, 126]
# 176 [1, 33, 144]
# 177 [1, 60, 118]
# 178 [1, 89, 90]
# 179 [1]
# 180 [1, 36, 45, 81, 100, 136, 145]
# 181 [1]
# 182 [1, 14, 78, 91, 92, 105, 169]
# 183 [1, 61, 123]
# 184 [1, 24, 161]
# 185 [1, 75, 111]
# 186 [1, 31, 63, 93, 94, 124, 156]
# 187 [1, 34, 154]
# 188 [1, 48, 141]
# 189 [1, 28, 162]
# 190 [1, 20, 76, 95, 96, 115, 171]
# 191 [1]
# 192 [1, 64, 129]
# 193 [1]
# 194 [1, 97, 98]
# 195 [1, 40, 66, 91, 105, 130, 156]
# 196 [1, 49, 148]
# 197 [1]
# 198 [1, 45, 55, 99, 100, 144, 154]
# 199 [1]
# 200 [1, 25, 176]
# 201 [1, 67, 135]
# 202 [1, 101, 102]
# 203 [1, 29, 175]
# 204 [1, 52, 69, 85, 120, 136, 153]
# 205 [1, 41, 165]
# 206 [1, 103, 104]
# 207 [1, 46, 162]
# 208 [1, 65, 144]
# 209 [1, 77, 133]
# 210 [1, 15, 21, 36, 70, 85, 91, 105, 106, 120, 126, 141, 175, 190, 196]
# 211 [1]
# 212 [1, 53, 160]
# 213 [1, 72, 142]
# 214 [1, 107, 108]
# 215 [1, 86, 130]
# 216 [1, 81, 136]
# 217 [1, 63, 155]
# 218 [1, 109, 110]
# 219 [1, 73, 147]
# 220 [1, 45, 56, 100, 121, 165, 176]
# 221 [1, 52, 170]
# 222 [1, 37, 75, 111, 112, 148, 186]
# 223 [1]
# 224 [1, 64, 161]
# 225 [1, 100, 126]
# 226 [1, 113, 114]
# 227 [1]
# 228 [1, 57, 76, 96, 133, 153, 172]
# 229 [1]
# 230 [1, 46, 70, 115, 116, 161, 185]
# 231 [1, 22, 78, 99, 133, 154, 210]
# 232 [1, 88, 145]
# 233 [1]
# 234 [1, 27, 91, 117, 118, 144, 208]
# 235 [1, 95, 141]
# 236 [1, 60, 177]
# 237 [1, 79, 159]
# 238 [1, 35, 85, 119, 120, 154, 204]
# 239 [1]
# 240 [1, 16, 81, 96, 145, 160, 225]
# 241 [1]
# 242 [1, 121, 122]
# 243 [1]
# 244 [1, 61, 184]
# 245 [1, 50, 196]
# 246 [1, 42, 82, 123, 124, 165, 205]
# 247 [1, 39, 209]
# 248 [1, 32, 217]
# 249 [1, 84, 166]
# 250 [1, 125, 126]
# 251 [1]
# 252 [1, 28, 36, 64, 189, 217, 225]
# 253 [1, 23, 231]
# 254 [1, 127, 128]
# 255 [1, 51, 85, 120, 136, 171, 205]
# 256 [1]
# 257 [1]
# 258 [1, 43, 87, 129, 130, 172, 216]
# 259 [1, 112, 148]
# 260 [1, 40, 65, 105, 156, 196, 221]
# 261 [1, 117, 145]
# 262 [1, 131, 132]
# 263 [1]
# 264 [1, 33, 88, 121, 144, 177, 232]
# 265 [1, 106, 160]
# 266 [1, 57, 77, 133, 134, 190, 210]
# 267 [1, 90, 178]
# 268 [1, 68, 201]
# 269 [1]
# 270 [1, 55, 81, 135, 136, 190, 216]
# 271 [1]
# 272 [1, 17, 256]
# 273 [1, 78, 91, 105, 169, 183, 196]
# 274 [1, 137, 138]
# 275 [1, 100, 176]
# 276 [1, 24, 69, 93, 184, 208, 253]
# 277 [1]
# 278 [1, 139, 140]
# 279 [1, 63, 217]
# 280 [1, 56, 105, 120, 161, 176, 225]
# 281 [1]
# 282 [1, 48, 94, 141, 142, 189, 235]
# 283 [1]
# 284 [1, 72, 213]
# 285 [1, 76, 96, 115, 171, 190, 210]
# 286 [1, 66, 78, 143, 144, 209, 221]
# 287 [1, 42, 246]
# 288 [1, 64, 225]
# 289 [1]
# 290 [1, 30, 116, 145, 146, 175, 261]
# 291 [1, 97, 195]
# 292 [1, 73, 220]
# 293 [1]
# 294 [1, 49, 99, 147, 148, 196, 246]
# 295 [1, 60, 236]
# 296 [1, 112, 185]
# 297 [1, 55, 243]
# 298 [1, 149, 150]
# 299 [1, 92, 208]
# 300 [1, 25, 76, 100, 201, 225, 276]
# 301 [1, 43, 259]
# 302 [1, 151, 152]
# 303 [1, 102, 202]
# 304 [1, 96, 209]
# 305 [1, 61, 245]
# 306 [1, 18, 136, 153, 154, 171, 289]
# 307 [1]
# 308 [1, 56, 77, 133, 176, 232, 253]
# 309 [1, 103, 207]
# 310 [1, 31, 125, 155, 156, 186, 280]
# 311 [1]
# 312 [1, 40, 105, 144, 169, 208, 273]
# 313 [1]
# 314 [1, 157, 158]
# 315 [1, 36, 91, 126, 190, 225, 280]
# 316 [1, 80, 237]
# 317 [1]
# 318 [1, 54, 106, 159, 160, 213, 265]
# 319 [1, 88, 232]
# 320 [1, 65, 256]
# 321 [1, 108, 214]
# 322 [1, 70, 92, 161, 162, 231, 253]
# 323 [1, 153, 171]
# 324 [1, 81, 244]
# 325 [1, 26, 300]
# 326 [1, 163, 164]
# 327 [1, 109, 219]
# 328 [1, 41, 288]
# 329 [1, 141, 189]
# 330 [1, 45, 55, 66, 100, 111, 121, 165, 166, 210, 220, 231, 265, 276, 286]
# 331 [1]
# 332 [1, 84, 249]
# 333 [1, 37, 297]
# 334 [1, 167, 168]
# 335 [1, 135, 201]
# 336 [1, 49, 64, 112, 225, 273, 288]
# 337 [1]
# 338 [1, 169, 170]
# 339 [1, 114, 226]
# 340 [1, 85, 120, 136, 205, 221, 256]
# 341 [1, 155, 187]
# 342 [1, 19, 153, 171, 172, 190, 324]
# 343 [1]
# 344 [1, 129, 216]
# 345 [1, 46, 70, 115, 231, 276, 300]
# 346 [1, 173, 174]
# 347 [1]
# 348 [1, 88, 117, 145, 204, 232, 261]
# 349 [1]
# 350 [1, 50, 126, 175, 176, 225, 301]
# 351 [1, 27, 325]
# 352 [1, 33, 320]
# 353 [1]
# 354 [1, 60, 118, 177, 178, 237, 295]
# 355 [1, 71, 285]
# 356 [1, 89, 268]
# 357 [1, 85, 120, 154, 204, 238, 273]
# 358 [1, 179, 180]
# 359 [1]
# 360 [1, 81, 136, 145, 216, 225, 280]
# 361 [1]
# 362 [1, 181, 182]
# 363 [1, 121, 243]
# 364 [1, 92, 105, 169, 196, 260, 273]
# 365 [1, 146, 220]
# 366 [1, 61, 123, 183, 184, 244, 306]
# 367 [1]
# 368 [1, 161, 208]
# 369 [1, 82, 288]
# 370 [1, 75, 111, 185, 186, 260, 296]
# 371 [1, 106, 266]
# 372 [1, 93, 124, 156, 217, 249, 280]
# 373 [1]
# 374 [1, 34, 154, 187, 188, 221, 341]
# 375 [1, 126, 250]
# 376 [1, 48, 329]
# 377 [1, 117, 261]
# 378 [1, 28, 162, 189, 190, 217, 351]
# 379 [1]
# 380 [1, 20, 76, 96, 285, 305, 361]
# 381 [1, 127, 255]
# 382 [1, 191, 192]
# 383 [1]
# 384 [1, 129, 256]
# 385 [1, 56, 155, 176, 210, 231, 330]
# 386 [1, 193, 194]
# 387 [1, 172, 216]
# 388 [1, 97, 292]
# 389 [1]
# 390 [1, 40, 66, 91, 105, 130, 156, 195, 196, 235, 261, 286, 300, 325, 351]
# 391 [1, 69, 323]
# 392 [1, 49, 344]
# 393 [1, 132, 262]
# 394 [1, 197, 198]
# 395 [1, 80, 316]
# 396 [1, 45, 100, 144, 253, 297, 352]
# 397 [1]
# 398 [1, 199, 200]
# 399 [1, 57, 133, 190, 210, 267, 343]
# 400 [1, 176, 225]
# 401 [1]
# 402 [1, 67, 135, 201, 202, 268, 336]
# 403 [1, 156, 248]
# 404 [1, 101, 304]
# 405 [1, 81, 325]
# 406 [1, 29, 175, 203, 204, 232, 378]
# 407 [1, 111, 297]
# 408 [1, 120, 136, 153, 256, 273, 289]
# 409 [1]
# 410 [1, 41, 165, 205, 206, 246, 370]
# 411 [1, 138, 274]
# 412 [1, 104, 309]
# 413 [1, 119, 295]
# 414 [1, 46, 162, 207, 208, 253, 369]
# 415 [1, 166, 250]
# 416 [1, 65, 352]
# 417 [1, 139, 279]
# 418 [1, 77, 133, 209, 210, 286, 342]
# 419 [1]
# 420 [1, 21, 36, 85, 105, 120, 141, 196, 225, 280, 301, 316, 336, 385, 400]
# 421 [1]
# 422 [1, 211, 212]
# 423 [1, 189, 235]
# 424 [1, 160, 265]
# 425 [1, 51, 375]
# 426 [1, 72, 142, 213, 214, 285, 355]
# 427 [1, 183, 245]
# 428 [1, 108, 321]
# 429 [1, 66, 78, 144, 286, 352, 364]
# 430 [1, 86, 130, 215, 216, 301, 345]
# 431 [1]
# 432 [1, 81, 352]
# 433 [1]
# 434 [1, 63, 155, 217, 218, 280, 372]
# 435 [1, 30, 145, 175, 261, 291, 406]
# 436 [1, 109, 328]
# 437 [1, 115, 323]
# 438 [1, 73, 147, 219, 220, 292, 366]
# 439 [1]
# 440 [1, 56, 121, 176, 265, 320, 385]
# 441 [1, 99, 343]
# 442 [1, 52, 170, 221, 222, 273, 391]
# 443 [1]
# 444 [1, 37, 112, 148, 297, 333, 408]
# 445 [1, 90, 356]
# 446 [1, 223, 224]
# 447 [1, 150, 298]
# 448 [1, 64, 385]
# 449 [1]
# 450 [1, 100, 126, 225, 226, 325, 351]
# 451 [1, 165, 287]
# 452 [1, 113, 340]
# 453 [1, 151, 303]
# 454 [1, 227, 228]
# 455 [1, 91, 105, 196, 260, 351, 365]
# 456 [1, 57, 96, 153, 304, 361, 400]
# 457 [1]
# 458 [1, 229, 230]
# 459 [1, 136, 324]
# 460 [1, 116, 161, 185, 276, 300, 345]
# 461 [1]
# 462 [1, 22, 78, 99, 133, 154, 210, 231, 232, 253, 309, 330, 364, 385, 441]
# 463 [1]
# 464 [1, 145, 320]
# 465 [1, 31, 156, 186, 280, 310, 435]
# 466 [1, 233, 234]
# 467 [1]
# 468 [1, 117, 144, 208, 261, 325, 352]
# 469 [1, 134, 336]
# 470 [1, 95, 141, 235, 236, 330, 376]
# 471 [1, 157, 315]
# 472 [1, 177, 296]
# 473 [1, 44, 430]
# 474 [1, 79, 159, 237, 238, 316, 396]
# 475 [1, 76, 400]
# 476 [1, 85, 120, 204, 273, 357, 392]
# 477 [1, 54, 424]
# 478 [1, 239, 240]
# 479 [1]
# 480 [1, 96, 160, 225, 256, 321, 385]
# 481 [1, 222, 260]
# 482 [1, 241, 242]
# 483 [1, 70, 162, 231, 253, 322, 414]
# 484 [1, 121, 364]
# 485 [1, 195, 291]
# 486 [1, 243, 244]
# 487 [1]
# 488 [1, 184, 305]
# 489 [1, 163, 327]
# 490 [1, 50, 196, 245, 246, 295, 441]
# 491 [1]
# 492 [1, 124, 165, 205, 288, 328, 369]
# 493 [1, 204, 290]
# 494 [1, 39, 209, 247, 248, 286, 456]
# 495 [1, 45, 55, 100, 396, 441, 451]
# 496 [1, 32, 465]
# 497 [1, 71, 427]
# 498 [1, 84, 166, 249, 250, 333, 415]
# 499 [1]

# %% [markdown]
# We observe that $n$ has $2^t-2$ values of $a$, where $t$ is the number of prime factors of $n$:

# %%
N = 50
for i in range(1, N):
    print(i, len(primeFactors(i, primes)), len(all_idempotents(i)))
# Out:
# 1 0 0
# 2 1 1
# 3 1 1
# 4 1 1
# 5 1 1
# 6 2 3
# 7 1 1
# 8 1 1
# 9 1 1
# 10 2 3
# 11 1 1
# 12 2 3
# 13 1 1
# 14 2 3
# 15 2 3
# 16 1 1
# 17 1 1
# 18 2 3
# 19 1 1
# 20 2 3
# 21 2 3
# 22 2 3
# 23 1 1
# 24 2 3
# 25 1 1
# 26 2 3
# 27 1 1
# 28 2 3
# 29 1 1
# 30 3 7
# 31 1 1
# 32 1 1
# 33 2 3
# 34 2 3
# 35 2 3
# 36 2 3
# 37 1 1
# 38 2 3
# 39 2 3
# 40 2 3
# 41 1 1
# 42 3 7
# 43 1 1
# 44 2 3
# 45 2 3
# 46 2 3
# 47 1 1
# 48 2 3
# 49 1 1

# %% [markdown]
# ## Bounds for $N$ given $a$
# Given $a$, it appears $N\leq a(a-1)$.

# %%
N = 500
a_target = 15
print(a_target, a_target*(a_target-1))
for i in range(1, N):
    all_a = all_idempotents(i)
    if a_target in all_a:
        print(i, all_a)
# Out:
# 15 210
# 21 [1, 7, 15]
# 30 [1, 6, 10, 15, 16, 21, 25]
# 35 [1, 15, 21]
# 42 [1, 7, 15, 21, 22, 28, 36]
# 70 [1, 15, 21, 35, 36, 50, 56]
# 105 [1, 15, 21, 36, 70, 85, 91]
# 210 [1, 15, 21, 36, 70, 85, 91, 105, 106, 120, 126, 141, 175, 190, 196]

# %% [markdown]
# ## Primal Divisor Property
#
# if $c|ab$, then there exists $c_1, c_2$ such that $c_1|a$, $c_2|b$, $c_1c_2=c$.
#
# So for this problem,
#
# if $c|a(a-1)$, then there exists $c_1, c_2$ such that $c_1|a$, $c_2|(a-1)$, $c_1c_2=c$.
#
# AND $c_1$ and $c_2$ share NO factors ($gcf(c_1, c_2) = 1$)

# %% [markdown]
# ## Which values of $N$ have $a$ as an idempotent?
# It appears there are $n_f/2 -1$ values of $N$ with $a$ as an idempotent, where $n_f$ is the number of factors of $a(a-1)$.

# %%
N = 4000
a_target = 11
print(a_target, a_target*(a_target-1))

idempotents = []
for i in range(1, N):
    all_a = all_idempotents(i)
    if a_target in all_a:
        idempotents.append(i)

print(f'number of factors of {a_target*(a_target-1)}:', len(factors(a_target*(a_target-1))))
print(f'number of values of N: {len(idempotents)}')
# Out:
# 11 110
# number of factors of 110: 8
# number of values of N: 3

# %% [markdown]
# ## which values of $N$ have $a$ as the LARGEST idempotent?
# There are NO $N$ such that $a_{max}$ is prime.

# %%
a_target = 17
print(primeFactors(a_target, primes))
N = a_target*(a_target-1) + 1

for i in range(2, N):
    all_a = all_idempotents(i)
    if a_target == max(all_a):
        print(i, max(all_a), all_a)
# Out:
# {17: 1}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6bf5d1201612> in <module>
#       4
#       5 for i in range(2, N):
# ----> 6     all_a = all_idempotents(i)
#       7     if a_target == max(all_a):
#       8         print(i, max(all_a), all_a)
#
# NameError: name 'all_idempotents' is not defined

# %% [markdown]
# ## If $a$ is even, then SOMETIMES $a=a_{max}$ for $N=2(a-1)$

# %%
for a in range(2, 50):
    N = a*(a-1) + 1
    
    for i in range(2, N):
        all_a = all_idempotents(i)
        if all_a == [1, a-1, a]:
            print(i, all_a, (a-1)*2)
# Out:
# 6 [1, 3, 4] 6
# 10 [1, 5, 6] 10
# 14 [1, 7, 8] 14
# 18 [1, 9, 10] 18
# 22 [1, 11, 12] 22
# 26 [1, 13, 14] 26
# 34 [1, 17, 18] 34
# 38 [1, 19, 20] 38
# 46 [1, 23, 24] 46
# 50 [1, 25, 26] 50
# 54 [1, 27, 28] 54
# 58 [1, 29, 30] 58
# 62 [1, 31, 32] 62
# 74 [1, 37, 38] 74
# 82 [1, 41, 42] 82
# 86 [1, 43, 44] 86
# 94 [1, 47, 48] 94

# %%
for a in range(2, 20):
    N = a*(a-1) + 1
    
    for i in range(2, N):
        all_a = all_idempotents(i)
        if a == max(all_a):
            print(a, i, all_a)
# Out:
# 4 6 [1, 3, 4]
# 6 10 [1, 5, 6]
# 8 14 [1, 7, 8]
# 9 12 [1, 4, 9]
# 10 15 [1, 6, 10]
# 10 18 [1, 9, 10]
# 12 22 [1, 11, 12]
# 14 26 [1, 13, 14]
# 15 21 [1, 7, 15]
# 16 20 [1, 5, 16]
# 16 24 [1, 9, 16]
# 18 34 [1, 17, 18]

# %%
from itertools import product

N = int(1e7)

a_max = [1]*(N+1)
fact_b = [1]
for a in range(N):
    if is_prime(a):
        fact_b = [1, a]
        continue
   
    if a%100000 == 0:
        print(a)
       
    fact_a = factors(a)
    fact_ab = [_a*b for _a, b in product(fact_a, fact_b)]
    n_candid = [_n for _n in fact_ab if _n > a and _n < N+1]
   
    for n in n_candid:
        a_max[n] = max(a_max[n], a)
    fact_b = fact_a

a_max[:2] = [0, 0]
print(sum(a_max))
# Out:
# 100000
# 200000
# 300000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-15382abd292e> in <module>
#      13         print(a)
#      14
# ---> 15     fact_a = factors(a)
#      16     fact_ab = [_a*b for _a, b in product(fact_a, fact_b)]
#      17     n_candid = [_n for _n in fact_ab if _n > a and _n < N+1]
#
# C:\Repositories\Project_Euler_Solutions\Python\EulerFunctions.py in factors(x)
#      76
#      77 def factors(x):
# ---> 78     factors = list([i, x//i] for i in range(1, int(pow(x, 0.5) + 1)) if x % i == 0)
#      79     return set(functools.reduce(list.__add__, factors))
#      80
#
# C:\Repositories\Project_Euler_Solutions\Python\EulerFunctions.py in <genexpr>(.0)
#      76
#      77 def factors(x):
# ---> 78     factors = list([i, x//i] for i in range(1, int(pow(x, 0.5) + 1)) if x % i == 0)
#      79     return set(functools.reduce(list.__add__, factors))
#      80
#
# KeyboardInterrupt:

# %%
for i, a in enumerate(a_max):
    print(i, a)
# Out:
# 0 1
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 4
# 7 1
# 8 1
# 9 1
# 10 6
# 11 1
# 12 9
# 13 1
# 14 8
# 15 10
# 16 1
# 17 1
# 18 10
# 19 1
# 20 16
# 21 15
# 22 12
# 23 1
# 24 16
# 25 1
# 26 14
# 27 1
# 28 21
# 29 1
# 30 25
# 31 1
# 32 1
# 33 22
# 34 18
# 35 21
# 36 28
# 37 1
# 38 20
# 39 27
# 40 25
# 41 1
# 42 36
# 43 1
# 44 33
# 45 36
# 46 24
# 47 1
# 48 33
# 49 1
# 50 26
# 51 34
# 52 40
# 53 1
# 54 28
# 55 45
# 56 49
# 57 39
# 58 30
# 59 1
# 60 45
# 61 1
# 62 32
# 63 36
# 64 1
# 65 40
# 66 55
# 67 1
# 68 52
# 69 46
# 70 56
# 71 1
# 72 64
# 73 1
# 74 38
# 75 51
# 76 57
# 77 56
# 78 66
# 79 1
# 80 65
# 81 1
# 82 42
# 83 1
# 84 64
# 85 51
# 86 44
# 87 58
# 88 56
# 89 1
# 90 81
# 91 78
# 92 69
# 93 63
# 94 48
# 95 76
# 96 64
# 97 1
# 98 50
# 99 55
# 100 1
